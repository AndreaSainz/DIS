# %%
[as3628@login-q-2 ~]$ cd c1_exmaple_classes/
[as3628@login-q-2 c1_exmaple_classes]$ git clone https://github.com/cmbant/getdist.git
Clonando en 'getdist'...
remote: Enumerating objects: 2401, done.
remote: Counting objects: 100% (845/845), done.
remote: Compressing objects: 100% (330/330), done.
remote: Total 2401 (delta 602), reused 739 (delta 510), pack-reused 1556 (from 1)
Recibiendo objetos: 100% (2401/2401), 57.78 MiB | 25.38 MiB/s, listo.
Resolviendo deltas: 100% (1719/1719), listo.

# %%
[as3628@login-q-2 c1_exmaple_classes]$ cd getdist/
[as3628@login-q-2 getdist]$ tree -L 2
.
├── codemeta.json
├── docs
│   ├── index.html
│   ├── plot_gallery.html
│   ├── plot_gallery.ipynb
│   └── source
├── getdist
│   ├── analysis_defaults.ini
│   ├── _base.py
│   ├── chain_grid.py
│   ├── chains.py
│   ├── cobaya_interface.py
│   ├── command_line.py
│   ├── convolve.py
│   ├── covcomb.py
│   ├── covmat.py
│   ├── covscale.py
│   ├── densities.py
│   ├── distparam_template.ini
│   ├── gaussian_mixtures.py
│   ├── gui
│   ├── inifile.py
│   ├── __init__.py
│   ├── kde_bandwidth.py
│   ├── matplotlib_ext.py
│   ├── mcsamples.py
│   ├── paramnames.py
│   ├── parampriors.py
│   ├── plots.py
│   ├── styles
│   ├── tests
│   ├── types.py
│   └── yaml_tools.py
├── GetDistGUI.py
├── LICENCE.txt
├── MANIFEST.in
├── pyproject.toml
├── README.rst
├── requirements.txt
└── setup.py

6 directories, 34 files

# %%
[as3628@login-q-3 c1_exmaple_classes]$ mkdir venvdir

# %%
[as3628@login-q-2 c1_exmaple_classes]$ cd venvdir/
[as3628@login-q-2 venvdir]$ module load miniconda/3
[as3628@login-q-2 venvdir]$ python --version
Python 3.7.4


[as3628@login-q-3 venvdir]$ python3
Python 3.7.4 (default, Aug 13 2019, 20:35:49) 
[GCC 7.3.0] :: Anaconda, Inc. on linux
Type "help", "copyright", "credits" or "license" for more information.

# %%
[as3628@login-q-3 venvdir]$ python3.11 -m venv venv_EC1_311
[as3628@login-q-3 venvdir]$ source venv_EC1_311/bin/activate
(venv_EC1_311) [as3628@login-q-3 venvdir]$ python -- version
python: can't open file '/home/as3628/c1_exmaple_classes/venvdir/version': [Errno 2] No such file or directory
(venv_EC1_311) [as3628@login-q-3 venvdir]$ python
Python 3.11.9 (main, Sep 24 2024, 09:39:15) [GCC 8.5.0 20210514 (Red Hat 8.5.0-22)] on linux
Type "help", "copyright", "credits" or "license" for more information.
>>> exit()

# %%
(venv_EC1_311) [as3628@login-q-2 ~]$ source c1_exmaple_classes/venvdir/venv_EC1_311/bin/activate
(venv_EC1_311) [as3628@login-q-2 ~]$ 
(venv_EC1_311) [as3628@login-q-2 ~]$ cd c1_exmaple_classes/getdist/
(venv_EC1_311) [as3628@login-q-2 getdist]$ pip install -e

Usage:   
  pip install [options] <requirement specifier> [package-index-options] ...
  pip install [options] -r <requirements file> [package-index-options] ...
  pip install [options] [-e] <vcs project url> ...
  pip install [options] [-e] <local project path> ...
  pip install [options] <archive url/path> ...

-e option requires 1 argument

# %%
(venv_EC1_311) [as3628@login-q-1 getdist]$ python
Python 3.11.9 (main, Sep 24 2024, 09:39:15) [GCC 8.5.0 20210514 (Red Hat 8.5.0-22)] on linux
Type "help", "copyright", "credits" or "license" for more information.
>>> import getdist
>>> getdist . __version__
'1.5.3'
>>> getdist . __file__
'/home/as3628/c1_exmaple_classes/getdist/getdist/__init__.py'

# %%
What is inside ec1.sh:

#!/bin/bash
echo "Hello $USER"

echo "The example class directory is $GOTOC1DIR"

tree -L 3 $GOTOC1DIR

ls -alh  $GOTOC1DIR

# Load the Miniconda3 module
module load miniconda/3

# Activate the virtual environment
source /home/as3628/c1_exmaple_classes/venvdir/venv_EC1_311/bin/activate







[as3628@login-q-1 c1_exmaple_classes]$ source ec1.sh 
Hello as3628
The example class directory is /home/as3628/c1_exmaple_classes
/home/as3628/c1_exmaple_classes
├── ec1.sh
├── getdist
│   ├── codemeta.json
│   ├── docs
│   │   ├── index.html
│   │   ├── plot_gallery.html
│   │   ├── plot_gallery.ipynb
│   │   └── source
│   ├── getdist
│   │   ├── analysis_defaults.ini
│   │   ├── _base.py
│   │   ├── chain_grid.py
│   │   ├── chains.py
│   │   ├── cobaya_interface.py
│   │   ├── command_line.py
│   │   ├── convolve.py
│   │   ├── covcomb.py
│   │   ├── covmat.py
│   │   ├── covscale.py
│   │   ├── densities.py
│   │   ├── distparam_template.ini
│   │   ├── gaussian_mixtures.py
│   │   ├── gui
│   │   ├── inifile.py
│   │   ├── __init__.py
│   │   ├── kde_bandwidth.py
│   │   ├── matplotlib_ext.py
│   │   ├── mcsamples.py
│   │   ├── paramnames.py
│   │   ├── parampriors.py
│   │   ├── plots.py
│   │   ├── styles
│   │   ├── tests
│   │   ├── types.py
│   │   └── yaml_tools.py
│   ├── GetDistGUI.py
│   ├── LICENCE.txt
│   ├── MANIFEST.in
│   ├── pyproject.toml
│   ├── README.rst
│   ├── requirements.txt
│   └── setup.py
└── venvdir
    └── venv_EC1_311
        ├── bin
        ├── include
        ├── lib
        ├── lib64 -> lib
        └── pyvenv.cfg

13 directories, 36 files
total 192K
drwxrwxr-x  4 as3628 as3628  74 oct 24 11:56 .
drwx------ 10 as3628 as3628 541 oct 25 09:25 ..
-rwxrwxr-x  1 as3628 as3628 287 oct 25 09:31 ec1.sh
drwxrwxr-x  6 as3628 as3628 429 oct 24 11:55 getdist
drwxrwxr-x  3 as3628 as3628  30 oct 24 11:58 venvdir
(venv_EC1_311) [as3628@login-q-1 c1_exmaple_classes]$ deactivate
