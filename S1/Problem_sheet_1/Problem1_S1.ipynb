# %% [markdown]
# QUESTIONS:
#
# 1. I can't use plt.style.use('mphil.mplstyle') (SOLVED)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

#plot style for publications
plt.style.use(r"/Users/andreasainz/Documents/DIS/First term code/DIS/mphil.mplstyle")

# %%
#Read data
df = pd.read_pickle(r"/Users/andreasainz/Documents/DIS/First term code/DIS/S1/First sheet/ps1.pkl")

# %%
#Show data
df
# Out:
#             vx        vy         vz        R2         p
# 0    -0.129486 -0.378220  -1.303648  0.159817  1.462786
# 1     0.855369  0.378654   2.219246  0.875035  3.138316
# 2    -0.391171  0.782003  -1.747694  0.764544  0.564914
# 3    -0.533835  1.830559  -1.869053  3.635927  1.814512
# 4    -1.001277 -0.443638  -6.325631  1.199371  0.855995
# ...        ...       ...        ...       ...       ...
# 4995 -0.767874 -0.409239   8.709525  0.757107  1.718384
# 4996 -0.307080 -0.407104   2.755963  0.260032  1.493122
# 4997  1.212534 -0.030045 -10.432455  1.471140  1.019734
# 4998  0.224905 -0.178124  10.580369  0.082310  0.102227
# 4999  0.720503  1.812312  -8.406622  3.803598  0.042884
#
# [5000 rows x 5 columns]

# %% [markdown]
# # section a

# %%
#pair plots of the distributions
sns.pairplot(df)

# %% [markdown]
# # section b

# %%
# Create the scatter plot
plt.scatter(df['vx'], df['vz'], s=30)

# Add a title (caption)
plt.title('Scatter Plot of vx versus vz')

# Add x-axis and y-axis labels
plt.xlabel('vx')
plt.ylabel('vz')

# Show the plot
plt.show()

# %% [markdown]
# ##### Add the density bar or something similar (with colour scale). Kernel Desnity Estimate. Probability content in the colour.
#
# In the caption its described what its in the graph.

# %% [markdown]
# # section c

# %%
#correlation matrix
cor_mat= df.corr()
cor_mat
# Out:
#           vx        vy        vz        R2         p
# vx  1.000000  0.499943 -0.283132  0.001504 -0.001291
# vy  0.499943  1.000000 -0.274027 -0.001331 -0.024314
# vz -0.283132 -0.274027  1.000000  0.008939  0.015736
# R2  0.001504 -0.001331  0.008939  1.000000  0.002401
# p  -0.001291 -0.024314  0.015736  0.002401  1.000000

# %%
#Heatmap of correlation matriz
plt.matshow(cor_mat)
plt.show()
# Out:
# /opt/anaconda3/envs/mphil/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#covariance matrix
cov_mat= df.cov()
cov_mat
# Out:
#           vx        vy          vz        R2         p
# vx  1.002608  0.493081   -2.852446  0.003324 -0.001334
# vy  0.493081  0.970208   -2.715740 -0.002893 -0.024699
# vz -2.852446 -2.715740  101.233585  0.198513  0.163291
# R2  0.003324 -0.002893    0.198513  4.871490  0.005466
# p  -0.001334 -0.024699    0.163291  0.005466  1.063632

# %%
#Heatmap of correlation matriz
plt.matshow(cov_mat)
plt.show()
# Out:
# /opt/anaconda3/envs/mphil/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)
